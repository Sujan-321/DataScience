# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %%
# scaling()
tips = sns.load_dataset('tips')
tips_demo = sns.load_dataset('tips')

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# MinMaxScaler() # It scale all values between 0 to 1

# %%
tips[['total_bill', 'tip']] = MinMaxScaler().fit_transform(tips[['total_bill', 'tip']])

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips_demo)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# ...

# %%
#used_cars_data(price, new_price)
from sklearn.preprocessing import LabelEncoder
df = pd.read_csv(r'C:\Users\Acer\Desktop\pandasPro\used_cars_data.csv', index_col=False)
encode_cols = ['Location', 'Fuel_Type', 'Transmission', 'Owner_Type']  # add 'brand' and 'model' also
for x in encode_cols:
    df[x] = LabelEncoder().fit_transform(df[x])

# %%
# df.drop(['Unnamed:0', 'New_Price', 'Price'], axis=1 , inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
sns.pairplot(df)

# %%
# Train and test
# overfitting
# underfitting



# machinelearning
# supervised
# unsupervised
# recognition
