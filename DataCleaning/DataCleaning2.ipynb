# %% [markdown]
# # What are the Methods to Handle Missing Values?
#     # a. Ignore missing Values row and columns by deleting row
#     # b. Fill missing values manually
#     # c. Global Constant
#     # d. Measure of central tendency (Mean, Median, Mode)
#     # e. Measure of central tencency for each class
#     # f. Most probable value (ML Algorithms)

# %% [markdown]
# # here we discuss about 'b', 'c' & 'd'. Missing Imputation by 'Mean', 'Median' & 'Mode'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load Dataset
# if we load data set from the googleDrive then
datasetPath = "https://drive.google.com/open?id=1BiGZSedP4BIIuTbVTBodOhVgFImaz08c"
# we should be replace 'open?' with 'uc?export=download&'
datasetPath = r"https://drive.google.com/uc?export=download&id=1BiGZSedP4BIIuTbVTBodOhVgFImaz08c"
df = pd.read_csv(datasetPath)

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType        872
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
# here we convert the number into percentage
missingValues = df.isnull().sum()/df.shape[0] * 100

# %%
missingValues
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
# Street            0.000000
# Alley            93.767123
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType       59.726027
# MasVnrArea        0.547945
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.534247
# BsmtCond          2.534247
# BsmtExposure      2.602740
# BsmtFinType1      2.534247
# ...

# %%
# let's remove more than 20% null data from the data set
miss_val = missingValues[missingValues > 20].keys()

# %%
miss_val
# Out:
# Index(['Alley', 'MasVnrType', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], dtype='object')

# %%
# dropping the missing values
df1 = df.copy()
df1 = df1.drop(columns=miss_val)

# %%
df1.shape
# Out:
# (1460, 75)

# %%
df2 = df1.select_dtypes(include=['int64', 'float64'])  # it store numerical values columns and 'object' columns were assign '0'
df2.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %%
# let's check the missing values using heatmap
plt.figure(figsize=(20, 20))
sns.heatmap(df2.isnull())
# Out:
# <Axes: >

# %%
df2[df2.isnull().any(axis=1)]
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 7        8          60          NaN    10382            7            6
# 12      13          20          NaN    12968            5            6
# 14      15          20          NaN    10920            6            5
# 16      17          20          NaN    11241            6            7
# 24      25          20          NaN     8246            5            8
# 31      32          20          NaN     8544            5            6
# 39      40          90         65.0     6040            4            5
# 42      43          85          NaN     9180            5            7
# 43      44          20          NaN     9200            5            6
# 48      49         190         33.0     4456            4            5
# 50      51          60          NaN    13869            6            6
# 64      65          60          NaN     9375            7            5
# ...

# %%
df2.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
missing_num_var = [var for var in df2.columns if df2[var].isnull().sum()>0]
missing_num_var
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
plt.figure(figsize=(20, 20))
sns.set()
for i, var in enumerate(missing_num_var):
    plt.subplot(2, 2, i+1)
    sns.distplot(df2[var], bins=20, kde_kws={"linewidth":5, 'color':'#DC143C'})
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_9368\3439805899.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2[var], bins=20, kde_kws={"linewidth":5, 'color':'#DC143C'})
# C:\Users\Acer\AppData\Local\Temp\ipykernel_9368\3439805899.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
df2.shape
# Out:
# (1460, 38)

# %%
# if the data is in normal distribution then we use 'Mean, Median and Mode' is use to fill those data.
# Normal Distribution : if the chart is bi-symmetrical(if cut in the middle two parts are equal) then is it known as Normal Distribution. For example:
                        # in the above chart 'LotFrontage' is Normal Distrbution


df3 = df2.fillna(df2.mean())   # here we take mean of every columns/variable and assign that mean in the 'N/A'
df3.isnull().sum().sum()
# Out:
# 0

# %%
plt.figure(figsize=(20, 20))
sns.set()
for i, var in enumerate(missing_num_var):
    plt.subplot(2, 2, i+1)
    sns.distplot(df2[var], bins=20, kde_kws={"linewidth":5, 'color':'red'}, label="Orginal")
    sns.distplot(df3[var], bins=20, kde_kws={"linewidth":3, 'color':'blue'}, label="Mean")
    plt.legend()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_9368\3855145742.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2[var], bins=20, kde_kws={"linewidth":5, 'color':'red'}, label="Orginal")
# C:\Users\Acer\AppData\Local\Temp\ipykernel_9368\3855145742.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
df4 = df2.fillna(df2.median())   # here we take mean of every columns/variable and assign that mean in the 'N/A'
df4.isnull().sum().sum()
# Out:
# 0

# %%
plt.figure(figsize=(20, 20))
sns.set()
for i, var in enumerate(missing_num_var):
    plt.subplot(2, 2, i+1)
    sns.distplot(df2[var], bins=20, kde_kws={"linewidth":8, 'color':'red'}, label="Orginal")
    sns.distplot(df3[var], bins=20, kde_kws={"linewidth":5, 'color':'green'}, label="Mean")
    sns.distplot(df4[var], bins=20, kde_kws={"linewidth":3, 'color':'blue'}, label="Median")
    plt.legend()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_9368\1421387469.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2[var], bins=20, kde_kws={"linewidth":8, 'color':'red'}, label="Orginal")
# C:\Users\Acer\AppData\Local\Temp\ipykernel_9368\1421387469.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
# let's discuss about the outlayer
for i, var in enumerate(missing_num_var):
    plt.figure(figsize=(20, 20))
    plt.subplot(3,1,1)
    sns.boxplot(x=df[var])  # display in horizontal format, that's why we use 'x=' parameter
    plt.subplot(3,1,2)
    sns.boxplot(x=df3[var])
    plt.subplot(3,1,3)
    sns.boxplot(x=df4[var])

plt.tight_layout()
plt.show()

# %%
# now let's do concatinate them for more prediction
df_concat = pd.concat([df2[missing_num_var], df3[missing_num_var], df4[missing_num_var]], axis=1)

# %%
df_concat[df_concat.isnull().any(axis=1)]
# Out:
#       LotFrontage  MasVnrArea  GarageYrBlt  LotFrontage  MasVnrArea  \
# 7             NaN       240.0       1973.0    70.049958  240.000000
# 12            NaN         0.0       1962.0    70.049958    0.000000
# 14            NaN       212.0       1960.0    70.049958  212.000000
# 16            NaN       180.0       1970.0    70.049958  180.000000
# 24            NaN         0.0       1968.0    70.049958    0.000000
# 31            NaN         0.0       1966.0    70.049958    0.000000
# 39           65.0         0.0          NaN    65.000000    0.000000
# 42            NaN         0.0       1983.0    70.049958    0.000000
# 43            NaN         0.0       1977.0    70.049958    0.000000
# 48           33.0         0.0          NaN    33.000000    0.000000
# 50            NaN         0.0       1997.0    70.049958    0.000000
# 64            NaN       573.0       1998.0    70.049958  573.000000
# 66            NaN       287.0       1970.0    70.049958  287.000000
# ...
